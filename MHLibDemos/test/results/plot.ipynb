# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %matplotlib inline
csv_path = Path("construction_results_experiments.csv")
df = pd.read_csv(csv_path)
df
# Out:
#                                   instance    n  nk  gamma    C     rho  \
# 0       instance1_nreq50_nveh2_gamma50.txt   50   2     50  100   40.08
# 1       instance1_nreq50_nveh2_gamma50.txt   50   2     50  100   40.08
# 2       instance1_nreq50_nveh2_gamma50.txt   50   2     50  100   40.08
# 3       instance1_nreq50_nveh2_gamma50.txt   50   2     50  100   40.08
# 4       instance1_nreq50_nveh2_gamma50.txt   50   2     50  100   40.08
# ..                                     ...  ...  ..    ...  ...     ...
# 395  instance14_nreq200_nveh4_gamma181.txt  200   4    181  100  298.81
# 396  instance14_nreq200_nveh4_gamma181.txt  200   4    181  100  298.81
# 397  instance14_nreq200_nveh4_gamma181.txt  200   4    181  100  298.81
# 398  instance14_nreq200_nveh4_gamma181.txt  200   4    181  100  298.81
# 399  instance14_nreq200_nveh4_gamma181.txt  200   4    181  100  298.81
#
#          alg  alpha  seed  total_time  fairness           obj  iters   runtime
# 0     nn_det    NaN     1      3113.0  1.977104   3192.242326    1.0  0.000689
# 1    nn_rand    0.0     1      4218.0  1.703999   4286.296263    1.0  0.005429
# 2    nn_rand    0.3     1      4218.0  1.703999   4286.296263    1.0  0.000875
# 3    nn_rand    0.7     1      4218.0  1.703999   4286.296263    1.0  0.000863
# 4     nn_det    NaN     2      3113.0  1.977104   3192.242326    1.0  0.003950
# ..       ...    ...   ...         ...       ...           ...    ...       ...
# 395  nn_rand    0.7     9     25306.0  3.850106  26456.450228    1.0  0.074484
# 396   nn_det    NaN    10     16695.0  3.771352  17821.917720    1.0  0.076931
# 397  nn_rand    0.0    10     26323.0  3.901391  27488.774781    1.0  0.080435
# 398  nn_rand    0.3    10     26323.0  3.901391  27488.774781    1.0  0.183785
# 399  nn_rand    0.7    10     26323.0  3.901391  27488.774781    1.0  0.080690
#
# [400 rows x 14 columns]
